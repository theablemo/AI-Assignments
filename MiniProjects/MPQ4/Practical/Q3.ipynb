# %% [markdown]
# <div align=center>
#
# <p></p>
# <p></p>
# <font size=5>
# In the Name of God
# <font/>
# <p></p>
#  <br/>
#     <br/>
#     <br/>
# <font color=#FF7500>
# Sharif University of Technology - Departmenet of Computer Engineering
# </font>
# <p></p>
# <font color=blue>
# Artifical Intelligence - Dr. Mohammad Hossein Rohban
# </font>
# <br/>
# <br/>
# Fall 2021
#
# </div>
#
# <hr/>
# 		<div align=center>
# 		    <font color=red size=6>
# 			    <br />
# Practical Assignment 4 - AutoEncoder
#             	<br/>
# 			</font>
#     <br/>
#     <br/>
# <font size=4>
#                 <br/><b>
#               Cheating is Strongly Prohibited
#                 </b><br/><br/>
#                 <font color=red>
# Please run all the cells.
#      </font>
# </font>
#                 <br/>
#     </div>

# %% [markdown]
# # Personal Data

# %%
# Set your student number
student_number = 98103867
Name = 'Mohammad'
Last_Name = 'Abolnejadian'

# %% [markdown]
# # Rules
# - You **are** allowed to add or remove cells.
# - By running the cell below, you can see if your jupyter file is accepted or not. This cell will also **generate a python file which you'll have to upload to Quera** (as well as your jupyter file). The python file will later be validated and if the code in both files doesn't match, **your Practical Assignment won't be graded**.

# %%
# remember to save your jupyter file before running this script
from Helper_codes.validator import *

python_code = extract_python("./Q3.ipynb")
with open(f'python_code_Q3_{student_number}.py', 'w') as file:
    file.write(python_code)
# Out:
# your file will be graded

# %% [markdown]
# # Autoencoders (25 Points Extra)

# %% [markdown]
# <font size=4>
# Author: Ahmad Salimi
# 			<br/>
#                 <font color=red>
# Please run all the cells.
#      </font>
# </font>
#                 <br/>
#     </div>

# %% [markdown]
# In this problem, you should implement an autoencoder network, which generates an image presenting the next digit of the input digit. Here are some examples:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# You should use the MNIST dataset, and the ground-truth for each example is provided by a helper function. Make sure to put the `ae_helper.py` file next to this notebook to use the helper function.

# %% [markdown]
# ## Get the data
#
# Get the data and split them into training, validation, and test sets, by running the following cell. `X` is the input images, `Y` is the ground-truth for each input, and `y` is the input's label.

# %%
from ae_helper import get_data
from sklearn.model_selection import train_test_split

X, Y, y = get_data()

X_train, X_test, Y_train, Y_test, y_train, y_test = train_test_split(X, Y, y, test_size=0.2, random_state=17)
X_train, X_val, Y_train, Y_val, y_train, y_val = train_test_split(X_train, Y_train, y_train, test_size=0.1, random_state=17)

# %% [markdown]
# ## Design your model
#
# Please Implement your autoencoder model below. You MUST implement your model using the `torch` package. The model should input a batch of images and output the generated images for the whole batch. Your model can be consist of fully connected layers (using linear layers), but using fully-convolutional models has extra points.

# %%
#imports
import torch
import torch.nn as nn
from typing import Tuple
from torch.utils.data import Dataset, DataLoader
import numpy as np
import pathlib

# %%
# device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device = torch.device('cpu')
device
# Out:
# device(type='cpu')

# %%
#### IMPLEMENT YOUR MODEL ####
class AutoEncoder(nn.Module):
  def __init__(self):
    super().__init__()
    self.encoder = torch.nn.Sequential(
            torch.nn.Linear(28 * 28, 128),
            torch.nn.ReLU(),
            torch.nn.Linear(128, 64),
            torch.nn.ReLU(),
            torch.nn.Linear(64, 36),
            torch.nn.ReLU(),
            torch.nn.Linear(36, 18),
            torch.nn.ReLU(),
            torch.nn.Linear(18, 9)
    )

    self.decoder = torch.nn.Sequential(
            torch.nn.Linear(9, 18),
            torch.nn.ReLU(),
            torch.nn.Linear(18, 36),
            torch.nn.ReLU(),
            torch.nn.Linear(36, 64),
            torch.nn.ReLU(),
            torch.nn.Linear(64, 128),
            torch.nn.ReLU(),
            torch.nn.Linear(128, 28 * 28),
            torch.nn.Sigmoid()
        )
  def forward(self, x: torch.Tensor) -> torch.Tensor:
    encoded = self.encoder(x)
    decoded = self.decoder(encoded)
    return decoded

# %% [markdown]
# ## The dataset class, and the dataloaders
#
# The following cells implement the dataset class and create the data loaders for training and validation sets. Feel free to modify the batch size for each data loader.

# %%
class MnistNextDigitDataset(Dataset):
    def __init__(self, X: np.ndarray, Y: np.ndarray, y: np.ndarray):
        self.X = torch.from_numpy(X)
        self.Y = torch.from_numpy(Y)
        self.y = torch.from_numpy(y)

    def __len__(self) -> int:
        return self.X.shape[0]

    def __getitem__(self, i: int) -> Tuple[torch.Tensor, ...]:
        return self.X[i], self.Y[i], self.y[i]

# %%
train_dataloader = DataLoader(
    MnistNextDigitDataset(X_train, Y_train, y_train),
    batch_size=512,
    shuffle=True
)
val_dataloader = DataLoader(
    MnistNextDigitDataset(X_val, Y_val, y_val),
    batch_size=1024,
    shuffle=False
)

# %% [markdown]
# ## Instantiate the model and optimizer
#
# Instantiate your model and optimizer in the following cell. Feel free to choose the optimizer and its configurations such as learning rate, decay, etc.

# %%
#### INSTANTIATE YOUR MODEL AND OPTIMIZER ####
model = AutoEncoder().to(device)
# criterion = nn.CrossEntropyLoss()
loss_function = torch.nn.MSELoss()
learning_rate = 1e-4
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %% [markdown]
# ## Train your autoencoder
#
# Write your training/validation loop in the following cell for an arbitrary number of epochs (until convergence is detected). Make sure to use proper and readable logging containing training and validation metrics for each epoch. Select and store the state dictionary of the best epoch model according to the metrics.

# %%
#### IMPLEMENT YOUR TRAIN/VAL LOOP ####
num_epochs = 100

train_loss_arr, val_loss_arr = [], []

best_loss = float("inf")
best_model = None

for epoch in range(num_epochs):
  train_loss, val_loss = 0, 0

  model.train()

  for i, (x, y, _) in enumerate(train_dataloader):
    x = x.to(device)
    y = y.to(device)
    p = model(torch.flatten(x, start_dim = 1))
    loss = loss_function(p, torch.flatten(y, start_dim = 1))
    # loss = criterion(p, y) * 512

    train_loss += float(loss)
    # predictions = p.argmax(-1)

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    

  model.eval()
  for i, (x, y, _) in enumerate(val_dataloader):
    x = x.to(device)
    y = y.to(device)
    p = model(torch.flatten(x, start_dim = 1))
    loss = loss_function(p, torch.flatten(y, start_dim = 1))
    # loss = criterion(p, y) * 1024

    val_loss += float(loss)
    # predictions = p.argmax(-1)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    

  train_loss /= len(train_dataloader.dataset)
  val_loss /= len(val_dataloader.dataset)
  epoch_loss = (train_loss + val_loss)/2
  if epoch_loss < best_loss:
    best_loss = epoch_loss
    best_model = model
  train_loss_arr.append(train_loss)
  val_loss_arr.append(val_loss)

  print(f"[Epoch {epoch}]\t"
      f"Train Loss: {train_loss:.8f}\t"
      f"Validation Loss: {val_loss:.8f}")

torch.save(best_model.state_dict(), 'state_dict_model.pt')
# Out:
# [Epoch 0]	Train Loss: 0.00011789	Validation Loss: 0.00006438
# [Epoch 1]	Train Loss: 0.00011754	Validation Loss: 0.00006420
# [Epoch 2]	Train Loss: 0.00011725	Validation Loss: 0.00006402
# [Epoch 3]	Train Loss: 0.00011694	Validation Loss: 0.00006386
# [Epoch 4]	Train Loss: 0.00011665	Validation Loss: 0.00006372
# [Epoch 5]	Train Loss: 0.00011643	Validation Loss: 0.00006359
# [Epoch 6]	Train Loss: 0.00011620	Validation Loss: 0.00006344
# [Epoch 7]	Train Loss: 0.00011596	Validation Loss: 0.00006334
# [Epoch 8]	Train Loss: 0.00011574	Validation Loss: 0.00006321
# [Epoch 9]	Train Loss: 0.00011554	Validation Loss: 0.00006308
# [Epoch 10]	Train Loss: 0.00011531	Validation Loss: 0.00006297
# [Epoch 11]	Train Loss: 0.00011511	Validation Loss: 0.00006289
# [Epoch 12]	Train Loss: 0.00011498	Validation Loss: 0.00006276
# [Epoch 13]	Train Loss: 0.00011476	Validation Loss: 0.00006266
# [Epoch 14]	Train Loss: 0.00011457	Validation Loss: 0.00006257
# [Epoch 15]	Train Loss: 0.00011438	Validation Loss: 0.00006246
# [Epoch 16]	Train Loss: 0.00011421	Validation Loss: 0.00006235
# [Epoch 17]	Train Loss: 0.00011404	Validation Loss: 0.00006226
# [Epoch 18]	Train Loss: 0.00011385	Validation Loss: 0.00006215
# [Epoch 19]	Train Loss: 0.00011367	Validation Loss: 0.00006202
# [Epoch 20]	Train Loss: 0.00011348	Validation Loss: 0.00006193
# [Epoch 21]	Train Loss: 0.00011330	Validation Loss: 0.00006181
# [Epoch 22]	Train Loss: 0.00011307	Validation Loss: 0.00006167
# [Epoch 23]	Train Loss: 0.00011282	Validation Loss: 0.00006153
# [Epoch 24]	Train Loss: 0.00011263	Validation Loss: 0.00006140
# [Epoch 25]	Train Loss: 0.00011240	Validation Loss: 0.00006129
# [Epoch 26]	Train Loss: 0.00011214	Validation Loss: 0.00006117
# [Epoch 27]	Train Loss: 0.00011195	Validation Loss: 0.00006105
# [Epoch 28]	Train Loss: 0.00011177	Validation Loss: 0.00006094
# [Epoch 29]	Train Loss: 0.00011158	Validation Loss: 0.00006086
# [Epoch 30]	Train Loss: 0.00011138	Validation Loss: 0.00006075
# [Epoch 31]	Train Loss: 0.00011117	Validation Loss: 0.00006064
# [Epoch 32]	Train Loss: 0.00011104	Validation Loss: 0.00006060
# [Epoch 33]	Train Loss: 0.00011089	Validation Loss: 0.00006047
# [Epoch 34]	Train Loss: 0.00011072	Validation Loss: 0.00006041
# [Epoch 35]	Train Loss: 0.00011057	Validation Loss: 0.00006031
# [Epoch 36]	Train Loss: 0.00011044	Validation Loss: 0.00006028
# [Epoch 37]	Train Loss: 0.00011032	Validation Loss: 0.00006019
# [Epoch 38]	Train Loss: 0.00011019	Validation Loss: 0.00006014
# [Epoch 39]	Train Loss: 0.00011009	Validation Loss: 0.00006007
# [Epoch 40]	Train Loss: 0.00011000	Validation Loss: 0.00006004
# [Epoch 41]	Train Loss: 0.00010989	Validation Loss: 0.00005998
# [Epoch 42]	Train Loss: 0.00010979	Validation Loss: 0.00005995
# [Epoch 43]	Train Loss: 0.00010971	Validation Loss: 0.00005990
# [Epoch 44]	Train Loss: 0.00010965	Validation Loss: 0.00005986
# [Epoch 45]	Train Loss: 0.00010956	Validation Loss: 0.00005982
# [Epoch 46]	Train Loss: 0.00010948	Validation Loss: 0.00005979
# [Epoch 47]	Train Loss: 0.00010945	Validation Loss: 0.00005976
# [Epoch 48]	Train Loss: 0.00010939	Validation Loss: 0.00005972
# [Epoch 49]	Train Loss: 0.00010933	Validation Loss: 0.00005971
# [Epoch 50]	Train Loss: 0.00010927	Validation Loss: 0.00005969
# [Epoch 51]	Train Loss: 0.00010920	Validation Loss: 0.00005965
# [Epoch 52]	Train Loss: 0.00010914	Validation Loss: 0.00005962
# [Epoch 53]	Train Loss: 0.00010908	Validation Loss: 0.00005960
# [Epoch 54]	Train Loss: 0.00010908	Validation Loss: 0.00005960
# [Epoch 55]	Train Loss: 0.00010897	Validation Loss: 0.00005955
# [Epoch 56]	Train Loss: 0.00010896	Validation Loss: 0.00005954
# [Epoch 57]	Train Loss: 0.00010889	Validation Loss: 0.00005951
# [Epoch 58]	Train Loss: 0.00010886	Validation Loss: 0.00005951
# [Epoch 59]	Train Loss: 0.00010881	Validation Loss: 0.00005949
# [Epoch 60]	Train Loss: 0.00010877	Validation Loss: 0.00005947
# [Epoch 61]	Train Loss: 0.00010872	Validation Loss: 0.00005944
# [Epoch 62]	Train Loss: 0.00010868	Validation Loss: 0.00005944
# [Epoch 63]	Train Loss: 0.00010866	Validation Loss: 0.00005944
# [Epoch 64]	Train Loss: 0.00010863	Validation Loss: 0.00005941
# [Epoch 65]	Train Loss: 0.00010857	Validation Loss: 0.00005937
# [Epoch 66]	Train Loss: 0.00010854	Validation Loss: 0.00005934
# [Epoch 67]	Train Loss: 0.00010850	Validation Loss: 0.00005936
# [Epoch 68]	Train Loss: 0.00010848	Validation Loss: 0.00005933
# [Epoch 69]	Train Loss: 0.00010846	Validation Loss: 0.00005930
# [Epoch 70]	Train Loss: 0.00010839	Validation Loss: 0.00005927
# [Epoch 71]	Train Loss: 0.00010837	Validation Loss: 0.00005929
# [Epoch 72]	Train Loss: 0.00010832	Validation Loss: 0.00005924
# [Epoch 73]	Train Loss: 0.00010829	Validation Loss: 0.00005925
# [Epoch 74]	Train Loss: 0.00010826	Validation Loss: 0.00005921
# [Epoch 75]	Train Loss: 0.00010824	Validation Loss: 0.00005921
# [Epoch 76]	Train Loss: 0.00010819	Validation Loss: 0.00005918
# [Epoch 77]	Train Loss: 0.00010817	Validation Loss: 0.00005925
# [Epoch 78]	Train Loss: 0.00010811	Validation Loss: 0.00005914
# [Epoch 79]	Train Loss: 0.00010809	Validation Loss: 0.00005915
# [Epoch 80]	Train Loss: 0.00010804	Validation Loss: 0.00005913
# [Epoch 81]	Train Loss: 0.00010799	Validation Loss: 0.00005910
# [Epoch 82]	Train Loss: 0.00010799	Validation Loss: 0.00005913
# [Epoch 83]	Train Loss: 0.00010797	Validation Loss: 0.00005908
# [Epoch 84]	Train Loss: 0.00010793	Validation Loss: 0.00005907
# [Epoch 85]	Train Loss: 0.00010793	Validation Loss: 0.00005905
# [Epoch 86]	Train Loss: 0.00010787	Validation Loss: 0.00005906
# [Epoch 87]	Train Loss: 0.00010784	Validation Loss: 0.00005904
# [Epoch 88]	Train Loss: 0.00010782	Validation Loss: 0.00005901
# [Epoch 89]	Train Loss: 0.00010779	Validation Loss: 0.00005901
# [Epoch 90]	Train Loss: 0.00010773	Validation Loss: 0.00005898
# [Epoch 91]	Train Loss: 0.00010770	Validation Loss: 0.00005899
# [Epoch 92]	Train Loss: 0.00010770	Validation Loss: 0.00005896
# [Epoch 93]	Train Loss: 0.00010766	Validation Loss: 0.00005895
# [Epoch 94]	Train Loss: 0.00010764	Validation Loss: 0.00005895
# [Epoch 95]	Train Loss: 0.00010758	Validation Loss: 0.00005895
# [Epoch 96]	Train Loss: 0.00010760	Validation Loss: 0.00005891
# [Epoch 97]	Train Loss: 0.00010759	Validation Loss: 0.00005891
# [Epoch 98]	Train Loss: 0.00010754	Validation Loss: 0.00005892
# [Epoch 99]	Train Loss: 0.00010750	Validation Loss: 0.00005892

# %% [markdown]
# ## Load the state dictionary of the best epoch
#
# Load the state dictionary of the best epoch model into the model object.

# %%
#### LOAD THE BEST EPOCH STATE DICTIONARY ####
trained_model = AutoEncoder().to(device)
trained_model.load_state_dict(torch.load('state_dict_model.pt'))
trained_model
# Out:
# AutoEncoder(
#   (encoder): Sequential(
#     (0): Linear(in_features=784, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=64, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=64, out_features=36, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=36, out_features=18, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=18, out_features=9, bias=True)
#   )
#   (decoder): Sequential(
#     (0): Linear(in_features=9, out_features=18, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=18, out_features=36, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=36, out_features=64, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=64, out_features=128, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=128, out_features=784, bias=True)
#     (9): Sigmoid()
#   )
# )

# %% [markdown]
# ## Visualize your model
#
# Select 40 examples from the test set and visualize the input and output of the model for them (See the examples at the beginning of the notebook).

# %%
#### VISUALIZE YOUR MODEL ####
test_dataloader = DataLoader(
    MnistNextDigitDataset(X_test, Y_test, y_test),
    batch_size=40,
    shuffle=True
)

trained_model.eval()

for j, (x, _, __) in enumerate(test_dataloader):
  x = x.to(device)
  p = trained_model(torch.flatten(x, start_dim = 1))
  fig, axes = plt.subplots(10, 8, figsize = (15,15))
  counter = 0
  for i in range(40):
    axes[int(counter/8)][counter%8].imshow(x[i])
    axes[int(counter/8)][counter%8].set_title("input")
    axes[int(counter/8)][counter%8].axis('off')
    counter += 1
    axes[int(counter/8)][counter%8].imshow(p[i].reshape([28, 28]).detach().numpy())
    axes[int(counter/8)][counter%8].set_title("output")
    axes[int(counter/8)][counter%8].axis('off')
    counter += 1
  break
